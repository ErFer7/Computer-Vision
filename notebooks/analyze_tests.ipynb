# %% [markdown]
# # Análise dos testes

# %% [markdown]
# ### Carregamento dos testes

# %%
from json import load

llama_quantized_test = load(open('../analysis/Llama-3.2-11B-Vision-Instruct_test_1000_class_only_quantized.json'))
llama_test = load(open('../analysis/Llama-3.2-11B-Vision-Instruct_test_1000_class_only.json'))
llama_derm_qlora_500 = load(open('../analysis/LLaMA_DERM_QLoRA_500_11B_test_1000_class_only.json'))
llama_derm_qlora_1000 = load(open('../analysis/LLaMA_DERM_QLoRA_1000_11B_test_1000_class_only.json'))
llama_derm_qlora_2000 = load(open('../analysis/LLaMA_DERM_QLoRA_2000_11B_test_1000_class_only.json'))
llama_derm_qlora_5000 = load(open('../analysis/LLaMA_DERM_QLoRA_5000_11B_test_1000_class_only.json'))
llama_derm_qlora_9500 = load(open('../analysis/LLaMA_DERM_QLoRA_9500_11B_test_1000_class_only.json'))
llama_derm_qlora_9500_train = load(open('../analysis/LLaMA_DERM_QLoRA_9500_11B_test_1000_class_only_train.json'))
llama_derm_lora_500 = load(open('../analysis/LLaMA_DERM_LoRA_500_11B_test_1000_class_only.json'))
llama_derm_lora_1000 = load(open('../analysis/LLaMA_DERM_LoRA_1000_11B_test_1000_class_only.json'))
llama_derm_lora_5000 = load(open('../analysis/LLaMA_DERM_LoRA_5000_11B_test_1000_class_only.json'))

# %% [markdown]
# ### Contagem das classes

# %%
from IPython.display import display, HTML
import pandas as pd
from collections import Counter


def create_distribution_table(counter: Counter, total: int, title: str) -> pd.DataFrame:
    """Create a formatted DataFrame from counter data"""
    df = pd.DataFrame([
        {
            'Answer': answer if len(answer) < 50 else answer[:51] + '...',
            'Count': count,
            'Percentage': count/total * 100
        }
        for answer, count in counter.items()
    ])

    df = df.sort_values('Count', ascending=False)
    df['Percentage'] = df['Percentage'].map('{:.1f}%'.format)

    # Style the table
    styled_df = df.style.set_caption(title).set_table_styles([
        {'selector': 'caption', 'props': [('font-weight', 'bold'), ('font-size', '120%')]},
        {'selector': 'th', 'props': [('text-align', 'left'), ('background-color', '#f0f0f0')]},
        {'selector': 'table', 'props': [('width', '100%')]},
    ]).hide(axis='index')

    return styled_df


def display_model_results(test_data, model_name):
    """Display expected vs actual results for a model"""
    results = test_data['results']
    expected_counter = Counter(item['expected'] for item in results)
    actual_counter = Counter(item['actual'] for item in results)

    total = len(results)

    display(HTML(f'<h2>{model_name}</h2>'))
    display(HTML("""
    <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
        <div>
            """ + create_distribution_table(expected_counter, total, 'Expected Classes Distribution').to_html() + """
        </div>
        <div>
            """ + create_distribution_table(actual_counter, total, 'Model Predictions Distribution').to_html() + """
        </div>
    </div>
    <br><hr><br>
    """))


tests = [
    (llama_quantized_test, 'LLaMA Base Model (Quantized)'),
    (llama_test, 'LLaMA Base Model'),
    (llama_derm_qlora_500, 'LLaMA + QLoRA (500 samples)'),
    (llama_derm_qlora_1000, 'LLaMA + QLoRA (1000 samples)'),
    (llama_derm_qlora_2000, 'LLaMA + QLoRA (2000 samples)'),
    (llama_derm_qlora_5000, 'LLaMA + QLoRA (5000 samples)'),
    (llama_derm_qlora_9500, 'LLaMA + QLoRA (9500 samples)'),
    (llama_derm_qlora_9500_train, 'LLaMA + QLoRA (9500 samples, test on training split)'),
    (llama_derm_lora_500, 'LLaMA + LoRA (500 samples)'),
    (llama_derm_lora_1000, 'LLaMA + LoRA (1000 samples)'),
    (llama_derm_lora_5000, 'LLaMA + LoRA (5000 samples)'),
]

for results, model_name in tests:
    display_model_results(results, model_name)
# Out:
# <h2>LLaMA Base Model (Quantized)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_6187a caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_6187a th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_6187a table {
#   width: 100%;
# }
# </style>
# <table id="T_6187a">
#   <caption>Expected Classes Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_6187a_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_6187a_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_6187a_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6187a_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_6187a_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_6187a_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_6187a_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_6187a_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_6187a_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_6187a_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_6187a_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_6187a_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_6187a_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_6187a_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_6187a_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_6187a_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_6187a_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_6187a_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_6187a_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_6187a_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_6187a_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_6187a_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_6187a_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_6187a_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_a059c caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_a059c th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_a059c table {
#   width: 100%;
# }
# </style>
# <table id="T_a059c">
#   <caption>Model Predictions Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_a059c_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_a059c_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_a059c_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a059c_row0_col0" class="data row0 col0" >Melanoma.</td>
#       <td id="T_a059c_row0_col1" class="data row0 col1" >976</td>
#       <td id="T_a059c_row0_col2" class="data row0 col2" >97.6%</td>
#     </tr>
#     <tr>
#       <td id="T_a059c_row1_col0" class="data row1 col0" >Melanocytic Nevi.</td>
#       <td id="T_a059c_row1_col1" class="data row1 col1" >13</td>
#       <td id="T_a059c_row1_col2" class="data row1 col2" >1.3%</td>
#     </tr>
#     <tr>
#       <td id="T_a059c_row2_col0" class="data row2 col0" >Dermatofibroma.</td>
#       <td id="T_a059c_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_a059c_row2_col2" class="data row2 col2" >0.8%</td>
#     </tr>
#     <tr>
#       <td id="T_a059c_row3_col0" class="data row3 col0" >**Step 1: Identify the characteristics of the skin ...</td>
#       <td id="T_a059c_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_a059c_row3_col2" class="data row3 col2" >0.1%</td>
#     </tr>
#     <tr>
#       <td id="T_a059c_row4_col0" class="data row4 col0" >**Step 1: Identify the key features of the skin les...</td>
#       <td id="T_a059c_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_a059c_row4_col2" class="data row4 col2" >0.1%</td>
#     </tr>
#     <tr>
#       <td id="T_a059c_row5_col0" class="data row5 col0" >**Step 1: Identify the characteristics of the skin ...</td>
#       <td id="T_a059c_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_a059c_row5_col2" class="data row5 col2" >0.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA Base Model</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_f827d caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_f827d th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_f827d table {
#   width: 100%;
# }
# </style>
# <table id="T_f827d">
#   <caption>Expected Classes Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_f827d_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_f827d_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_f827d_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f827d_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_f827d_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_f827d_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_f827d_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_f827d_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_f827d_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_f827d_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_f827d_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_f827d_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_f827d_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_f827d_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_f827d_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_f827d_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_f827d_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_f827d_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_f827d_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_f827d_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_f827d_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_f827d_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_f827d_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_f827d_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_4bfce caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_4bfce th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_4bfce table {
#   width: 100%;
# }
# </style>
# <table id="T_4bfce">
#   <caption>Model Predictions Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_4bfce_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_4bfce_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_4bfce_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4bfce_row0_col0" class="data row0 col0" >Melanoma.</td>
#       <td id="T_4bfce_row0_col1" class="data row0 col1" >883</td>
#       <td id="T_4bfce_row0_col2" class="data row0 col2" >88.3%</td>
#     </tr>
#     <tr>
#       <td id="T_4bfce_row1_col0" class="data row1 col0" >Dermatofibroma.</td>
#       <td id="T_4bfce_row1_col1" class="data row1 col1" >64</td>
#       <td id="T_4bfce_row1_col2" class="data row1 col2" >6.4%</td>
#     </tr>
#     <tr>
#       <td id="T_4bfce_row2_col0" class="data row2 col0" >Melanocytic Nevi.</td>
#       <td id="T_4bfce_row2_col1" class="data row2 col1" >51</td>
#       <td id="T_4bfce_row2_col2" class="data row2 col2" >5.1%</td>
#     </tr>
#     <tr>
#       <td id="T_4bfce_row3_col0" class="data row3 col0" >Actinic keratoses.</td>
#       <td id="T_4bfce_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_4bfce_row3_col2" class="data row3 col2" >0.1%</td>
#     </tr>
#     <tr>
#       <td id="T_4bfce_row4_col0" class="data row4 col0" >**Step 1: Identify the characteristics of the skin ...</td>
#       <td id="T_4bfce_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_4bfce_row4_col2" class="data row4 col2" >0.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + QLoRA (500 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_60405 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_60405 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_60405 table {
#   width: 100%;
# }
# </style>
# <table id="T_60405">
#   <caption>Expected Classes Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_60405_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_60405_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_60405_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_60405_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_60405_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_60405_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_60405_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_60405_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_60405_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_60405_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_60405_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_60405_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_60405_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_60405_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_60405_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_60405_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_60405_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_60405_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_60405_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_60405_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_60405_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_60405_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_60405_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_60405_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_c73fe caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_c73fe th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_c73fe table {
#   width: 100%;
# }
# </style>
# <table id="T_c73fe">
#   <caption>Model Predictions Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_c73fe_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_c73fe_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_c73fe_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c73fe_row0_col0" class="data row0 col0" >The skin lesion in the image is melanocytic Nevi.</td>
#       <td id="T_c73fe_row0_col1" class="data row0 col1" >737</td>
#       <td id="T_c73fe_row0_col2" class="data row0 col2" >73.7%</td>
#     </tr>
#     <tr>
#       <td id="T_c73fe_row1_col0" class="data row1 col0" >The skin lesion in the image is melanoma.</td>
#       <td id="T_c73fe_row1_col1" class="data row1 col1" >149</td>
#       <td id="T_c73fe_row1_col2" class="data row1 col2" >14.9%</td>
#     </tr>
#     <tr>
#       <td id="T_c73fe_row2_col0" class="data row2 col0" >Melanocytic Nevi.</td>
#       <td id="T_c73fe_row2_col1" class="data row2 col1" >75</td>
#       <td id="T_c73fe_row2_col2" class="data row2 col2" >7.5%</td>
#     </tr>
#     <tr>
#       <td id="T_c73fe_row3_col0" class="data row3 col0" >Melanoma.</td>
#       <td id="T_c73fe_row3_col1" class="data row3 col1" >22</td>
#       <td id="T_c73fe_row3_col2" class="data row3 col2" >2.2%</td>
#     </tr>
#     <tr>
#       <td id="T_c73fe_row4_col0" class="data row4 col0" >The skin lesion in the image is benign keratosis-li...</td>
#       <td id="T_c73fe_row4_col1" class="data row4 col1" >13</td>
#       <td id="T_c73fe_row4_col2" class="data row4 col2" >1.3%</td>
#     </tr>
#     <tr>
#       <td id="T_c73fe_row5_col0" class="data row5 col0" >Actinic keratoses.</td>
#       <td id="T_c73fe_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_c73fe_row5_col2" class="data row5 col2" >0.3%</td>
#     </tr>
#     <tr>
#       <td id="T_c73fe_row6_col0" class="data row6 col0" >The skin lesion in the image is vascular lesions.</td>
#       <td id="T_c73fe_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_c73fe_row6_col2" class="data row6 col2" >0.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + QLoRA (1000 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_c9f71 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_c9f71 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_c9f71 table {
#   width: 100%;
# }
# </style>
# <table id="T_c9f71">
#   <caption>Expected Classes Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_c9f71_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_c9f71_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_c9f71_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c9f71_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_c9f71_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_c9f71_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_c9f71_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_c9f71_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_c9f71_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_c9f71_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_c9f71_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_c9f71_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_c9f71_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_c9f71_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_c9f71_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_c9f71_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_c9f71_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_c9f71_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_c9f71_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_c9f71_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_c9f71_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_c9f71_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_c9f71_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_c9f71_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_6fb27 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_6fb27 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_6fb27 table {
#   width: 100%;
# }
# </style>
# <table id="T_6fb27">
#   <caption>Model Predictions Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_6fb27_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_6fb27_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_6fb27_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6fb27_row0_col0" class="data row0 col0" >Melanocytic Nevi.</td>
#       <td id="T_6fb27_row0_col1" class="data row0 col1" >582</td>
#       <td id="T_6fb27_row0_col2" class="data row0 col2" >58.2%</td>
#     </tr>
#     <tr>
#       <td id="T_6fb27_row1_col0" class="data row1 col0" >Melanoma.</td>
#       <td id="T_6fb27_row1_col1" class="data row1 col1" >213</td>
#       <td id="T_6fb27_row1_col2" class="data row1 col2" >21.3%</td>
#     </tr>
#     <tr>
#       <td id="T_6fb27_row2_col0" class="data row2 col0" >Actinic keratoses.</td>
#       <td id="T_6fb27_row2_col1" class="data row2 col1" >130</td>
#       <td id="T_6fb27_row2_col2" class="data row2 col2" >13.0%</td>
#     </tr>
#     <tr>
#       <td id="T_6fb27_row3_col0" class="data row3 col0" >melanoma.</td>
#       <td id="T_6fb27_row3_col1" class="data row3 col1" >25</td>
#       <td id="T_6fb27_row3_col2" class="data row3 col2" >2.5%</td>
#     </tr>
#     <tr>
#       <td id="T_6fb27_row4_col0" class="data row4 col0" >melanocytic Nevi.</td>
#       <td id="T_6fb27_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_6fb27_row4_col2" class="data row4 col2" >2.0%</td>
#     </tr>
#     <tr>
#       <td id="T_6fb27_row5_col0" class="data row5 col0" >actinic keratoses.</td>
#       <td id="T_6fb27_row5_col1" class="data row5 col1" >13</td>
#       <td id="T_6fb27_row5_col2" class="data row5 col2" >1.3%</td>
#     </tr>
#     <tr>
#       <td id="T_6fb27_row6_col0" class="data row6 col0" >Basal cell carcinoma.</td>
#       <td id="T_6fb27_row6_col1" class="data row6 col1" >12</td>
#       <td id="T_6fb27_row6_col2" class="data row6 col2" >1.2%</td>
#     </tr>
#     <tr>
#       <td id="T_6fb27_row7_col0" class="data row7 col0" >vascular lesions.</td>
#       <td id="T_6fb27_row7_col1" class="data row7 col1" >5</td>
#       <td id="T_6fb27_row7_col2" class="data row7 col2" >0.5%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + QLoRA (2000 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_3f829 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_3f829 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_3f829 table {
#   width: 100%;
# }
# </style>
# <table id="T_3f829">
#   <caption>Expected Classes Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_3f829_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_3f829_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_3f829_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3f829_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_3f829_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_3f829_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_3f829_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_3f829_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_3f829_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_3f829_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_3f829_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_3f829_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_3f829_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_3f829_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_3f829_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_3f829_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_3f829_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_3f829_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_3f829_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_3f829_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_3f829_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_3f829_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_3f829_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_3f829_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_9a7b4 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_9a7b4 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_9a7b4 table {
#   width: 100%;
# }
# </style>
# <table id="T_9a7b4">
#   <caption>Model Predictions Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_9a7b4_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_9a7b4_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_9a7b4_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9a7b4_row0_col0" class="data row0 col0" >melanocytic Nevi.</td>
#       <td id="T_9a7b4_row0_col1" class="data row0 col1" >677</td>
#       <td id="T_9a7b4_row0_col2" class="data row0 col2" >67.7%</td>
#     </tr>
#     <tr>
#       <td id="T_9a7b4_row1_col0" class="data row1 col0" >melanoma.</td>
#       <td id="T_9a7b4_row1_col1" class="data row1 col1" >151</td>
#       <td id="T_9a7b4_row1_col2" class="data row1 col2" >15.1%</td>
#     </tr>
#     <tr>
#       <td id="T_9a7b4_row2_col0" class="data row2 col0" >actinic keratoses.</td>
#       <td id="T_9a7b4_row2_col1" class="data row2 col1" >126</td>
#       <td id="T_9a7b4_row2_col2" class="data row2 col2" >12.6%</td>
#     </tr>
#     <tr>
#       <td id="T_9a7b4_row3_col0" class="data row3 col0" >Basal cell carcinoma.</td>
#       <td id="T_9a7b4_row3_col1" class="data row3 col1" >15</td>
#       <td id="T_9a7b4_row3_col2" class="data row3 col2" >1.5%</td>
#     </tr>
#     <tr>
#       <td id="T_9a7b4_row4_col0" class="data row4 col0" >vascular lesions.</td>
#       <td id="T_9a7b4_row4_col1" class="data row4 col1" >14</td>
#       <td id="T_9a7b4_row4_col2" class="data row4 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_9a7b4_row5_col0" class="data row5 col0" >Melanocytic Nevi.</td>
#       <td id="T_9a7b4_row5_col1" class="data row5 col1" >11</td>
#       <td id="T_9a7b4_row5_col2" class="data row5 col2" >1.1%</td>
#     </tr>
#     <tr>
#       <td id="T_9a7b4_row6_col0" class="data row6 col0" >basal cell carcinoma.</td>
#       <td id="T_9a7b4_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_9a7b4_row6_col2" class="data row6 col2" >0.2%</td>
#     </tr>
#     <tr>
#       <td id="T_9a7b4_row7_col0" class="data row7 col0" >The skin lesion in the image is melanocytic Nevi.</td>
#       <td id="T_9a7b4_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_9a7b4_row7_col2" class="data row7 col2" >0.1%</td>
#     </tr>
#     <tr>
#       <td id="T_9a7b4_row8_col0" class="data row8 col0" >Melocytic Nevi.</td>
#       <td id="T_9a7b4_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_9a7b4_row8_col2" class="data row8 col2" >0.1%</td>
#     </tr>
#     <tr>
#       <td id="T_9a7b4_row9_col0" class="data row9 col0" >Actinic keratoses.</td>
#       <td id="T_9a7b4_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_9a7b4_row9_col2" class="data row9 col2" >0.1%</td>
#     </tr>
#     <tr>
#       <td id="T_9a7b4_row10_col0" class="data row10 col0" >dermatofibroma.</td>
#       <td id="T_9a7b4_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_9a7b4_row10_col2" class="data row10 col2" >0.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + QLoRA (5000 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_5581c caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_5581c th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_5581c table {
#   width: 100%;
# }
# </style>
# <table id="T_5581c">
#   <caption>Expected Classes Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_5581c_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_5581c_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_5581c_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5581c_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_5581c_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_5581c_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_5581c_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_5581c_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_5581c_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_5581c_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_5581c_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_5581c_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_5581c_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_5581c_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_5581c_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_5581c_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_5581c_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_5581c_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_5581c_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_5581c_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_5581c_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_5581c_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_5581c_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_5581c_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_9d16e caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_9d16e th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_9d16e table {
#   width: 100%;
# }
# </style>
# <table id="T_9d16e">
#   <caption>Model Predictions Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_9d16e_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_9d16e_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_9d16e_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9d16e_row0_col0" class="data row0 col0" >The skin lesion in the image is melanocytic Nevi.</td>
#       <td id="T_9d16e_row0_col1" class="data row0 col1" >699</td>
#       <td id="T_9d16e_row0_col2" class="data row0 col2" >69.9%</td>
#     </tr>
#     <tr>
#       <td id="T_9d16e_row1_col0" class="data row1 col0" >The skin lesion in the image is melanoma.</td>
#       <td id="T_9d16e_row1_col1" class="data row1 col1" >113</td>
#       <td id="T_9d16e_row1_col2" class="data row1 col2" >11.3%</td>
#     </tr>
#     <tr>
#       <td id="T_9d16e_row2_col0" class="data row2 col0" >The skin lesion in the image is benign keratosis-li...</td>
#       <td id="T_9d16e_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_9d16e_row2_col2" class="data row2 col2" >9.0%</td>
#     </tr>
#     <tr>
#       <td id="T_9d16e_row3_col0" class="data row3 col0" >The skin lesion in the image is basal cell carcinom...</td>
#       <td id="T_9d16e_row3_col1" class="data row3 col1" >51</td>
#       <td id="T_9d16e_row3_col2" class="data row3 col2" >5.1%</td>
#     </tr>
#     <tr>
#       <td id="T_9d16e_row4_col0" class="data row4 col0" >The skin lesion in the image is actinic keratoses....</td>
#       <td id="T_9d16e_row4_col1" class="data row4 col1" >30</td>
#       <td id="T_9d16e_row4_col2" class="data row4 col2" >3.0%</td>
#     </tr>
#     <tr>
#       <td id="T_9d16e_row5_col0" class="data row5 col0" >The skin lesion in the image is vascular lesions.</td>
#       <td id="T_9d16e_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_9d16e_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_9d16e_row6_col0" class="data row6 col0" >The skin lesion in the image is dermatofibroma.</td>
#       <td id="T_9d16e_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_9d16e_row6_col2" class="data row6 col2" >0.3%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + QLoRA (9500 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_08da1 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_08da1 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_08da1 table {
#   width: 100%;
# }
# </style>
# <table id="T_08da1">
#   <caption>Expected Classes Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_08da1_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_08da1_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_08da1_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_08da1_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_08da1_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_08da1_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_08da1_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_08da1_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_08da1_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_08da1_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_08da1_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_08da1_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_08da1_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_08da1_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_08da1_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_08da1_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_08da1_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_08da1_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_08da1_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_08da1_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_08da1_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_08da1_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_08da1_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_08da1_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_12c48 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_12c48 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_12c48 table {
#   width: 100%;
# }
# </style>
# <table id="T_12c48">
#   <caption>Model Predictions Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_12c48_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_12c48_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_12c48_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_12c48_row0_col0" class="data row0 col0" >The skin lesion in the image is melanocytic Nevi.</td>
#       <td id="T_12c48_row0_col1" class="data row0 col1" >742</td>
#       <td id="T_12c48_row0_col2" class="data row0 col2" >74.2%</td>
#     </tr>
#     <tr>
#       <td id="T_12c48_row1_col0" class="data row1 col0" >The skin lesion in the image is benign keratosis-li...</td>
#       <td id="T_12c48_row1_col1" class="data row1 col1" >78</td>
#       <td id="T_12c48_row1_col2" class="data row1 col2" >7.8%</td>
#     </tr>
#     <tr>
#       <td id="T_12c48_row2_col0" class="data row2 col0" >The skin lesion in the image is basal cell carcinom...</td>
#       <td id="T_12c48_row2_col1" class="data row2 col1" >59</td>
#       <td id="T_12c48_row2_col2" class="data row2 col2" >5.9%</td>
#     </tr>
#     <tr>
#       <td id="T_12c48_row3_col0" class="data row3 col0" >The skin lesion in the image is actinic keratoses....</td>
#       <td id="T_12c48_row3_col1" class="data row3 col1" >54</td>
#       <td id="T_12c48_row3_col2" class="data row3 col2" >5.4%</td>
#     </tr>
#     <tr>
#       <td id="T_12c48_row4_col0" class="data row4 col0" >The skin lesion in the image is melanoma.</td>
#       <td id="T_12c48_row4_col1" class="data row4 col1" >49</td>
#       <td id="T_12c48_row4_col2" class="data row4 col2" >4.9%</td>
#     </tr>
#     <tr>
#       <td id="T_12c48_row5_col0" class="data row5 col0" >The skin lesion in the image is vascular lesions.</td>
#       <td id="T_12c48_row5_col1" class="data row5 col1" >13</td>
#       <td id="T_12c48_row5_col2" class="data row5 col2" >1.3%</td>
#     </tr>
#     <tr>
#       <td id="T_12c48_row6_col0" class="data row6 col0" >The skin lesion in the image is dermatofibroma.</td>
#       <td id="T_12c48_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_12c48_row6_col2" class="data row6 col2" >0.5%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + QLoRA (9500 samples, test on training split)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_f4d9e caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_f4d9e th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_f4d9e table {
#   width: 100%;
# }
# </style>
# <table id="T_f4d9e">
#   <caption>Expected Classes Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_f4d9e_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_f4d9e_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_f4d9e_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f4d9e_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_f4d9e_row0_col1" class="data row0 col1" >669</td>
#       <td id="T_f4d9e_row0_col2" class="data row0 col2" >66.9%</td>
#     </tr>
#     <tr>
#       <td id="T_f4d9e_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_f4d9e_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_f4d9e_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_f4d9e_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_f4d9e_row2_col1" class="data row2 col1" >109</td>
#       <td id="T_f4d9e_row2_col2" class="data row2 col2" >10.9%</td>
#     </tr>
#     <tr>
#       <td id="T_f4d9e_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_f4d9e_row3_col1" class="data row3 col1" >51</td>
#       <td id="T_f4d9e_row3_col2" class="data row3 col2" >5.1%</td>
#     </tr>
#     <tr>
#       <td id="T_f4d9e_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_f4d9e_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_f4d9e_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_f4d9e_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_f4d9e_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_f4d9e_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_f4d9e_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_f4d9e_row6_col1" class="data row6 col1" >12</td>
#       <td id="T_f4d9e_row6_col2" class="data row6 col2" >1.2%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_03e4c caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_03e4c th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_03e4c table {
#   width: 100%;
# }
# </style>
# <table id="T_03e4c">
#   <caption>Model Predictions Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_03e4c_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_03e4c_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_03e4c_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_03e4c_row0_col0" class="data row0 col0" >The skin lesion in the image is melanocytic Nevi.</td>
#       <td id="T_03e4c_row0_col1" class="data row0 col1" >748</td>
#       <td id="T_03e4c_row0_col2" class="data row0 col2" >74.8%</td>
#     </tr>
#     <tr>
#       <td id="T_03e4c_row1_col0" class="data row1 col0" >The skin lesion in the image is benign keratosis-li...</td>
#       <td id="T_03e4c_row1_col1" class="data row1 col1" >77</td>
#       <td id="T_03e4c_row1_col2" class="data row1 col2" >7.7%</td>
#     </tr>
#     <tr>
#       <td id="T_03e4c_row2_col0" class="data row2 col0" >The skin lesion in the image is actinic keratoses....</td>
#       <td id="T_03e4c_row2_col1" class="data row2 col1" >54</td>
#       <td id="T_03e4c_row2_col2" class="data row2 col2" >5.4%</td>
#     </tr>
#     <tr>
#       <td id="T_03e4c_row3_col0" class="data row3 col0" >The skin lesion in the image is melanoma.</td>
#       <td id="T_03e4c_row3_col1" class="data row3 col1" >51</td>
#       <td id="T_03e4c_row3_col2" class="data row3 col2" >5.1%</td>
#     </tr>
#     <tr>
#       <td id="T_03e4c_row4_col0" class="data row4 col0" >The skin lesion in the image is basal cell carcinom...</td>
#       <td id="T_03e4c_row4_col1" class="data row4 col1" >48</td>
#       <td id="T_03e4c_row4_col2" class="data row4 col2" >4.8%</td>
#     </tr>
#     <tr>
#       <td id="T_03e4c_row5_col0" class="data row5 col0" >The skin lesion in the image is vascular lesions.</td>
#       <td id="T_03e4c_row5_col1" class="data row5 col1" >13</td>
#       <td id="T_03e4c_row5_col2" class="data row5 col2" >1.3%</td>
#     </tr>
#     <tr>
#       <td id="T_03e4c_row6_col0" class="data row6 col0" >The skin lesion in the image is dermatofibroma.</td>
#       <td id="T_03e4c_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_03e4c_row6_col2" class="data row6 col2" >0.9%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + LoRA (500 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_41b41 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_41b41 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_41b41 table {
#   width: 100%;
# }
# </style>
# <table id="T_41b41">
#   <caption>Expected Classes Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_41b41_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_41b41_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_41b41_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_41b41_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_41b41_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_41b41_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_41b41_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_41b41_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_41b41_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_41b41_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_41b41_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_41b41_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_41b41_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_41b41_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_41b41_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_41b41_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_41b41_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_41b41_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_41b41_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_41b41_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_41b41_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_41b41_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_41b41_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_41b41_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_8f181 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_8f181 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_8f181 table {
#   width: 100%;
# }
# </style>
# <table id="T_8f181">
#   <caption>Model Predictions Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_8f181_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_8f181_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_8f181_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8f181_row0_col0" class="data row0 col0" >Melanocytic Nevi.</td>
#       <td id="T_8f181_row0_col1" class="data row0 col1" >598</td>
#       <td id="T_8f181_row0_col2" class="data row0 col2" >59.8%</td>
#     </tr>
#     <tr>
#       <td id="T_8f181_row1_col0" class="data row1 col0" >Melanoma.</td>
#       <td id="T_8f181_row1_col1" class="data row1 col1" >384</td>
#       <td id="T_8f181_row1_col2" class="data row1 col2" >38.4%</td>
#     </tr>
#     <tr>
#       <td id="T_8f181_row2_col0" class="data row2 col0" >Basal cell carcinoma.</td>
#       <td id="T_8f181_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_8f181_row2_col2" class="data row2 col2" >1.0%</td>
#     </tr>
#     <tr>
#       <td id="T_8f181_row3_col0" class="data row3 col0" >Actinic keratoses.</td>
#       <td id="T_8f181_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_8f181_row3_col2" class="data row3 col2" >0.7%</td>
#     </tr>
#     <tr>
#       <td id="T_8f181_row4_col0" class="data row4 col0" >Dermatofibroma.</td>
#       <td id="T_8f181_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_8f181_row4_col2" class="data row4 col2" >0.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + LoRA (1000 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_c8c34 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_c8c34 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_c8c34 table {
#   width: 100%;
# }
# </style>
# <table id="T_c8c34">
#   <caption>Expected Classes Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_c8c34_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_c8c34_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_c8c34_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c8c34_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_c8c34_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_c8c34_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_c8c34_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_c8c34_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_c8c34_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_c8c34_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_c8c34_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_c8c34_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_c8c34_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_c8c34_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_c8c34_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_c8c34_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_c8c34_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_c8c34_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_c8c34_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_c8c34_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_c8c34_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_c8c34_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_c8c34_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_c8c34_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_fbd6d caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_fbd6d th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_fbd6d table {
#   width: 100%;
# }
# </style>
# <table id="T_fbd6d">
#   <caption>Model Predictions Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_fbd6d_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_fbd6d_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_fbd6d_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fbd6d_row0_col0" class="data row0 col0" >Melanoma.</td>
#       <td id="T_fbd6d_row0_col1" class="data row0 col1" >567</td>
#       <td id="T_fbd6d_row0_col2" class="data row0 col2" >56.7%</td>
#     </tr>
#     <tr>
#       <td id="T_fbd6d_row1_col0" class="data row1 col0" >Melanocytic Nevi.</td>
#       <td id="T_fbd6d_row1_col1" class="data row1 col1" >408</td>
#       <td id="T_fbd6d_row1_col2" class="data row1 col2" >40.8%</td>
#     </tr>
#     <tr>
#       <td id="T_fbd6d_row2_col0" class="data row2 col0" >Actinic keratoses.</td>
#       <td id="T_fbd6d_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_fbd6d_row2_col2" class="data row2 col2" >1.3%</td>
#     </tr>
#     <tr>
#       <td id="T_fbd6d_row3_col0" class="data row3 col0" >Basal cell carcinoma.</td>
#       <td id="T_fbd6d_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_fbd6d_row3_col2" class="data row3 col2" >0.8%</td>
#     </tr>
#     <tr>
#       <td id="T_fbd6d_row4_col0" class="data row4 col0" >Dermatofibroma.</td>
#       <td id="T_fbd6d_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_fbd6d_row4_col2" class="data row4 col2" >0.4%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + LoRA (5000 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_81ca7 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_81ca7 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_81ca7 table {
#   width: 100%;
# }
# </style>
# <table id="T_81ca7">
#   <caption>Expected Classes Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_81ca7_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_81ca7_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_81ca7_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_81ca7_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_81ca7_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_81ca7_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_81ca7_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_81ca7_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_81ca7_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_81ca7_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_81ca7_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_81ca7_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_81ca7_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_81ca7_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_81ca7_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_81ca7_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_81ca7_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_81ca7_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_81ca7_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_81ca7_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_81ca7_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_81ca7_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_81ca7_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_81ca7_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_ca1fc caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_ca1fc th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_ca1fc table {
#   width: 100%;
# }
# </style>
# <table id="T_ca1fc">
#   <caption>Model Predictions Distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_ca1fc_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_ca1fc_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_ca1fc_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ca1fc_row0_col0" class="data row0 col0" >The skin lesion in the image is melanocytic Nevi.</td>
#       <td id="T_ca1fc_row0_col1" class="data row0 col1" >716</td>
#       <td id="T_ca1fc_row0_col2" class="data row0 col2" >71.6%</td>
#     </tr>
#     <tr>
#       <td id="T_ca1fc_row1_col0" class="data row1 col0" >The skin lesion in the image is melanoma.</td>
#       <td id="T_ca1fc_row1_col1" class="data row1 col1" >117</td>
#       <td id="T_ca1fc_row1_col2" class="data row1 col2" >11.7%</td>
#     </tr>
#     <tr>
#       <td id="T_ca1fc_row2_col0" class="data row2 col0" >The skin lesion in the image is benign keratosis-li...</td>
#       <td id="T_ca1fc_row2_col1" class="data row2 col1" >66</td>
#       <td id="T_ca1fc_row2_col2" class="data row2 col2" >6.6%</td>
#     </tr>
#     <tr>
#       <td id="T_ca1fc_row3_col0" class="data row3 col0" >The skin lesion in the image is basal cell carcinom...</td>
#       <td id="T_ca1fc_row3_col1" class="data row3 col1" >60</td>
#       <td id="T_ca1fc_row3_col2" class="data row3 col2" >6.0%</td>
#     </tr>
#     <tr>
#       <td id="T_ca1fc_row4_col0" class="data row4 col0" >The skin lesion in the image is actinic keratoses....</td>
#       <td id="T_ca1fc_row4_col1" class="data row4 col1" >26</td>
#       <td id="T_ca1fc_row4_col2" class="data row4 col2" >2.6%</td>
#     </tr>
#     <tr>
#       <td id="T_ca1fc_row5_col0" class="data row5 col0" >The skin lesion in the image is vascular lesions.</td>
#       <td id="T_ca1fc_row5_col1" class="data row5 col1" >12</td>
#       <td id="T_ca1fc_row5_col2" class="data row5 col2" >1.2%</td>
#     </tr>
#     <tr>
#       <td id="T_ca1fc_row6_col0" class="data row6 col0" >The skin lesion in the image is dermatofibroma.</td>
#       <td id="T_ca1fc_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_ca1fc_row6_col2" class="data row6 col2" >0.3%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>

# %% [markdown]
# ### Processamento dos testes

# %%
from collections import Counter
import re

DISEASE_CLASSES = [
    'melanocytic Nevi',
    'melanoma',
    'benign keratosis-like lesions',
    'basal cell carcinoma',
    'actinic keratoses',
    'vascular lesions',
    'dermatofibroma'
]


def normalize_disease(text: str) -> str:
    """Normalize disease name to standard format"""
    text = text.lower().strip().strip('.')

    # Common variations mapping
    variations = {
        'melanocytic nevi': 'melanocytic Nevi',
        'nevus': 'melanocytic Nevi',
        'nevi': 'melanocytic Nevi',
        'melanoma': 'melanoma',
        'benign keratosis': 'benign keratosis-like lesions',
        'seborrheic keratosis': 'benign keratosis-like lesions',
        'basal cell': 'basal cell carcinoma',
        'actinic keratosis': 'actinic keratoses',
        'vascular': 'vascular lesions'
    }

    for variant, standard in variations.items():
        if variant in text:
            return standard

    return text


def classify_answer(text: str) -> str:
    """Classify model answer into standard disease class or unclear"""
    text = text.lower()

    # Count mentioned diseases
    mentioned_diseases = []
    for disease in DISEASE_CLASSES:
        if disease.lower() in text:
            mentioned_diseases.append(disease)

    # Handle classification
    if len(mentioned_diseases) != 1:
        return 'unclear answer'
    else:
        return mentioned_diseases[0]


def process_and_display_results(test_data: dict, model_name: str) -> list[tuple[str, str]]:
    """Process and display results with standardized classifications. Returns list of (expected, classified) pairs"""
    results = test_data['results']
    total = len(results)

    # Process answers and create pairs
    processed_results = [
        {
            'expected': result['expected'],
            'actual': result['actual'],
            'classified': classify_answer(result['actual'])
        }
        for result in results
    ]

    # Create pairs list
    pairs = [(r['expected'], r['classified']) for r in processed_results]

    expected_counter = Counter(item['expected'] for item in processed_results)
    classified_counter = Counter(item['classified'] for item in processed_results)

    # Display results
    display(HTML(f'<h2>{model_name}</h2>'))
    display(HTML("""
    <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
        <div>
            """ + create_distribution_table(expected_counter, total, 'Expected Classes').to_html() + """
        </div>
        <div>
            """ + create_distribution_table(classified_counter, total, 'Classified Predictions').to_html() + """
        </div>
    </div>
    <br><hr><br>
    """))

    return pairs


all_results = {}
for test_data, model_name in tests:
    all_results[model_name] = process_and_display_results(test_data, model_name)
# Out:
# <h2>LLaMA Base Model (Quantized)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_f9931 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_f9931 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_f9931 table {
#   width: 100%;
# }
# </style>
# <table id="T_f9931">
#   <caption>Expected Classes</caption>
#   <thead>
#     <tr>
#       <th id="T_f9931_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_f9931_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_f9931_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f9931_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_f9931_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_f9931_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_f9931_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_f9931_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_f9931_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_f9931_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_f9931_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_f9931_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_f9931_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_f9931_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_f9931_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_f9931_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_f9931_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_f9931_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_f9931_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_f9931_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_f9931_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_f9931_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_f9931_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_f9931_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_fa6c5 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_fa6c5 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_fa6c5 table {
#   width: 100%;
# }
# </style>
# <table id="T_fa6c5">
#   <caption>Classified Predictions</caption>
#   <thead>
#     <tr>
#       <th id="T_fa6c5_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_fa6c5_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_fa6c5_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fa6c5_row0_col0" class="data row0 col0" >melanoma</td>
#       <td id="T_fa6c5_row0_col1" class="data row0 col1" >976</td>
#       <td id="T_fa6c5_row0_col2" class="data row0 col2" >97.6%</td>
#     </tr>
#     <tr>
#       <td id="T_fa6c5_row1_col0" class="data row1 col0" >melanocytic Nevi</td>
#       <td id="T_fa6c5_row1_col1" class="data row1 col1" >13</td>
#       <td id="T_fa6c5_row1_col2" class="data row1 col2" >1.3%</td>
#     </tr>
#     <tr>
#       <td id="T_fa6c5_row2_col0" class="data row2 col0" >dermatofibroma</td>
#       <td id="T_fa6c5_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_fa6c5_row2_col2" class="data row2 col2" >0.8%</td>
#     </tr>
#     <tr>
#       <td id="T_fa6c5_row3_col0" class="data row3 col0" >unclear answer</td>
#       <td id="T_fa6c5_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_fa6c5_row3_col2" class="data row3 col2" >0.3%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA Base Model</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_7168e caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_7168e th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_7168e table {
#   width: 100%;
# }
# </style>
# <table id="T_7168e">
#   <caption>Expected Classes</caption>
#   <thead>
#     <tr>
#       <th id="T_7168e_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_7168e_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_7168e_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7168e_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_7168e_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_7168e_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_7168e_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_7168e_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_7168e_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_7168e_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_7168e_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_7168e_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_7168e_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_7168e_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_7168e_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_7168e_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_7168e_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_7168e_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_7168e_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_7168e_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_7168e_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_7168e_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_7168e_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_7168e_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_38b60 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_38b60 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_38b60 table {
#   width: 100%;
# }
# </style>
# <table id="T_38b60">
#   <caption>Classified Predictions</caption>
#   <thead>
#     <tr>
#       <th id="T_38b60_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_38b60_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_38b60_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_38b60_row0_col0" class="data row0 col0" >melanoma</td>
#       <td id="T_38b60_row0_col1" class="data row0 col1" >883</td>
#       <td id="T_38b60_row0_col2" class="data row0 col2" >88.3%</td>
#     </tr>
#     <tr>
#       <td id="T_38b60_row1_col0" class="data row1 col0" >dermatofibroma</td>
#       <td id="T_38b60_row1_col1" class="data row1 col1" >64</td>
#       <td id="T_38b60_row1_col2" class="data row1 col2" >6.4%</td>
#     </tr>
#     <tr>
#       <td id="T_38b60_row2_col0" class="data row2 col0" >melanocytic Nevi</td>
#       <td id="T_38b60_row2_col1" class="data row2 col1" >51</td>
#       <td id="T_38b60_row2_col2" class="data row2 col2" >5.1%</td>
#     </tr>
#     <tr>
#       <td id="T_38b60_row3_col0" class="data row3 col0" >actinic keratoses</td>
#       <td id="T_38b60_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_38b60_row3_col2" class="data row3 col2" >0.1%</td>
#     </tr>
#     <tr>
#       <td id="T_38b60_row4_col0" class="data row4 col0" >unclear answer</td>
#       <td id="T_38b60_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_38b60_row4_col2" class="data row4 col2" >0.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + QLoRA (500 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_1dca9 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_1dca9 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_1dca9 table {
#   width: 100%;
# }
# </style>
# <table id="T_1dca9">
#   <caption>Expected Classes</caption>
#   <thead>
#     <tr>
#       <th id="T_1dca9_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_1dca9_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_1dca9_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1dca9_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_1dca9_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_1dca9_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_1dca9_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_1dca9_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_1dca9_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_1dca9_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_1dca9_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_1dca9_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_1dca9_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_1dca9_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_1dca9_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_1dca9_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_1dca9_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_1dca9_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_1dca9_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_1dca9_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_1dca9_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_1dca9_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_1dca9_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_1dca9_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_87a34 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_87a34 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_87a34 table {
#   width: 100%;
# }
# </style>
# <table id="T_87a34">
#   <caption>Classified Predictions</caption>
#   <thead>
#     <tr>
#       <th id="T_87a34_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_87a34_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_87a34_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_87a34_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_87a34_row0_col1" class="data row0 col1" >812</td>
#       <td id="T_87a34_row0_col2" class="data row0 col2" >81.2%</td>
#     </tr>
#     <tr>
#       <td id="T_87a34_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_87a34_row1_col1" class="data row1 col1" >171</td>
#       <td id="T_87a34_row1_col2" class="data row1 col2" >17.1%</td>
#     </tr>
#     <tr>
#       <td id="T_87a34_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_87a34_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_87a34_row2_col2" class="data row2 col2" >1.3%</td>
#     </tr>
#     <tr>
#       <td id="T_87a34_row3_col0" class="data row3 col0" >actinic keratoses</td>
#       <td id="T_87a34_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_87a34_row3_col2" class="data row3 col2" >0.3%</td>
#     </tr>
#     <tr>
#       <td id="T_87a34_row4_col0" class="data row4 col0" >vascular lesions</td>
#       <td id="T_87a34_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_87a34_row4_col2" class="data row4 col2" >0.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + QLoRA (1000 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_0307f caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_0307f th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_0307f table {
#   width: 100%;
# }
# </style>
# <table id="T_0307f">
#   <caption>Expected Classes</caption>
#   <thead>
#     <tr>
#       <th id="T_0307f_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_0307f_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_0307f_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0307f_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_0307f_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_0307f_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_0307f_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_0307f_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_0307f_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_0307f_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_0307f_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_0307f_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_0307f_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_0307f_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_0307f_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_0307f_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_0307f_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_0307f_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_0307f_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_0307f_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_0307f_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_0307f_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_0307f_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_0307f_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_4eec2 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_4eec2 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_4eec2 table {
#   width: 100%;
# }
# </style>
# <table id="T_4eec2">
#   <caption>Classified Predictions</caption>
#   <thead>
#     <tr>
#       <th id="T_4eec2_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_4eec2_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_4eec2_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4eec2_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_4eec2_row0_col1" class="data row0 col1" >602</td>
#       <td id="T_4eec2_row0_col2" class="data row0 col2" >60.2%</td>
#     </tr>
#     <tr>
#       <td id="T_4eec2_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_4eec2_row1_col1" class="data row1 col1" >238</td>
#       <td id="T_4eec2_row1_col2" class="data row1 col2" >23.8%</td>
#     </tr>
#     <tr>
#       <td id="T_4eec2_row2_col0" class="data row2 col0" >actinic keratoses</td>
#       <td id="T_4eec2_row2_col1" class="data row2 col1" >143</td>
#       <td id="T_4eec2_row2_col2" class="data row2 col2" >14.3%</td>
#     </tr>
#     <tr>
#       <td id="T_4eec2_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_4eec2_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_4eec2_row3_col2" class="data row3 col2" >1.2%</td>
#     </tr>
#     <tr>
#       <td id="T_4eec2_row4_col0" class="data row4 col0" >vascular lesions</td>
#       <td id="T_4eec2_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_4eec2_row4_col2" class="data row4 col2" >0.5%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + QLoRA (2000 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_27ae3 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_27ae3 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_27ae3 table {
#   width: 100%;
# }
# </style>
# <table id="T_27ae3">
#   <caption>Expected Classes</caption>
#   <thead>
#     <tr>
#       <th id="T_27ae3_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_27ae3_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_27ae3_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_27ae3_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_27ae3_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_27ae3_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_27ae3_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_27ae3_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_27ae3_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_27ae3_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_27ae3_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_27ae3_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_27ae3_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_27ae3_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_27ae3_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_27ae3_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_27ae3_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_27ae3_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_27ae3_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_27ae3_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_27ae3_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_27ae3_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_27ae3_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_27ae3_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_c0b97 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_c0b97 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_c0b97 table {
#   width: 100%;
# }
# </style>
# <table id="T_c0b97">
#   <caption>Classified Predictions</caption>
#   <thead>
#     <tr>
#       <th id="T_c0b97_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_c0b97_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_c0b97_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c0b97_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_c0b97_row0_col1" class="data row0 col1" >689</td>
#       <td id="T_c0b97_row0_col2" class="data row0 col2" >68.9%</td>
#     </tr>
#     <tr>
#       <td id="T_c0b97_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_c0b97_row1_col1" class="data row1 col1" >151</td>
#       <td id="T_c0b97_row1_col2" class="data row1 col2" >15.1%</td>
#     </tr>
#     <tr>
#       <td id="T_c0b97_row2_col0" class="data row2 col0" >actinic keratoses</td>
#       <td id="T_c0b97_row2_col1" class="data row2 col1" >127</td>
#       <td id="T_c0b97_row2_col2" class="data row2 col2" >12.7%</td>
#     </tr>
#     <tr>
#       <td id="T_c0b97_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_c0b97_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_c0b97_row3_col2" class="data row3 col2" >1.7%</td>
#     </tr>
#     <tr>
#       <td id="T_c0b97_row4_col0" class="data row4 col0" >vascular lesions</td>
#       <td id="T_c0b97_row4_col1" class="data row4 col1" >14</td>
#       <td id="T_c0b97_row4_col2" class="data row4 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_c0b97_row5_col0" class="data row5 col0" >unclear answer</td>
#       <td id="T_c0b97_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_c0b97_row5_col2" class="data row5 col2" >0.1%</td>
#     </tr>
#     <tr>
#       <td id="T_c0b97_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_c0b97_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_c0b97_row6_col2" class="data row6 col2" >0.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + QLoRA (5000 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_9f119 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_9f119 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_9f119 table {
#   width: 100%;
# }
# </style>
# <table id="T_9f119">
#   <caption>Expected Classes</caption>
#   <thead>
#     <tr>
#       <th id="T_9f119_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_9f119_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_9f119_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9f119_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_9f119_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_9f119_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_9f119_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_9f119_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_9f119_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_9f119_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_9f119_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_9f119_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_9f119_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_9f119_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_9f119_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_9f119_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_9f119_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_9f119_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_9f119_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_9f119_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_9f119_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_9f119_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_9f119_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_9f119_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_ec040 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_ec040 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_ec040 table {
#   width: 100%;
# }
# </style>
# <table id="T_ec040">
#   <caption>Classified Predictions</caption>
#   <thead>
#     <tr>
#       <th id="T_ec040_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_ec040_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_ec040_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ec040_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_ec040_row0_col1" class="data row0 col1" >699</td>
#       <td id="T_ec040_row0_col2" class="data row0 col2" >69.9%</td>
#     </tr>
#     <tr>
#       <td id="T_ec040_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_ec040_row1_col1" class="data row1 col1" >113</td>
#       <td id="T_ec040_row1_col2" class="data row1 col2" >11.3%</td>
#     </tr>
#     <tr>
#       <td id="T_ec040_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_ec040_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_ec040_row2_col2" class="data row2 col2" >9.0%</td>
#     </tr>
#     <tr>
#       <td id="T_ec040_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_ec040_row3_col1" class="data row3 col1" >51</td>
#       <td id="T_ec040_row3_col2" class="data row3 col2" >5.1%</td>
#     </tr>
#     <tr>
#       <td id="T_ec040_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_ec040_row4_col1" class="data row4 col1" >30</td>
#       <td id="T_ec040_row4_col2" class="data row4 col2" >3.0%</td>
#     </tr>
#     <tr>
#       <td id="T_ec040_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_ec040_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_ec040_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_ec040_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_ec040_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_ec040_row6_col2" class="data row6 col2" >0.3%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + QLoRA (9500 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_37de5 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_37de5 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_37de5 table {
#   width: 100%;
# }
# </style>
# <table id="T_37de5">
#   <caption>Expected Classes</caption>
#   <thead>
#     <tr>
#       <th id="T_37de5_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_37de5_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_37de5_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_37de5_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_37de5_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_37de5_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_37de5_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_37de5_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_37de5_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_37de5_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_37de5_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_37de5_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_37de5_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_37de5_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_37de5_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_37de5_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_37de5_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_37de5_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_37de5_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_37de5_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_37de5_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_37de5_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_37de5_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_37de5_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_4c2f8 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_4c2f8 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_4c2f8 table {
#   width: 100%;
# }
# </style>
# <table id="T_4c2f8">
#   <caption>Classified Predictions</caption>
#   <thead>
#     <tr>
#       <th id="T_4c2f8_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_4c2f8_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_4c2f8_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4c2f8_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_4c2f8_row0_col1" class="data row0 col1" >742</td>
#       <td id="T_4c2f8_row0_col2" class="data row0 col2" >74.2%</td>
#     </tr>
#     <tr>
#       <td id="T_4c2f8_row1_col0" class="data row1 col0" >benign keratosis-like lesions</td>
#       <td id="T_4c2f8_row1_col1" class="data row1 col1" >78</td>
#       <td id="T_4c2f8_row1_col2" class="data row1 col2" >7.8%</td>
#     </tr>
#     <tr>
#       <td id="T_4c2f8_row2_col0" class="data row2 col0" >basal cell carcinoma</td>
#       <td id="T_4c2f8_row2_col1" class="data row2 col1" >59</td>
#       <td id="T_4c2f8_row2_col2" class="data row2 col2" >5.9%</td>
#     </tr>
#     <tr>
#       <td id="T_4c2f8_row3_col0" class="data row3 col0" >actinic keratoses</td>
#       <td id="T_4c2f8_row3_col1" class="data row3 col1" >54</td>
#       <td id="T_4c2f8_row3_col2" class="data row3 col2" >5.4%</td>
#     </tr>
#     <tr>
#       <td id="T_4c2f8_row4_col0" class="data row4 col0" >melanoma</td>
#       <td id="T_4c2f8_row4_col1" class="data row4 col1" >49</td>
#       <td id="T_4c2f8_row4_col2" class="data row4 col2" >4.9%</td>
#     </tr>
#     <tr>
#       <td id="T_4c2f8_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_4c2f8_row5_col1" class="data row5 col1" >13</td>
#       <td id="T_4c2f8_row5_col2" class="data row5 col2" >1.3%</td>
#     </tr>
#     <tr>
#       <td id="T_4c2f8_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_4c2f8_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_4c2f8_row6_col2" class="data row6 col2" >0.5%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + QLoRA (9500 samples, test on training split)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_9b17a caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_9b17a th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_9b17a table {
#   width: 100%;
# }
# </style>
# <table id="T_9b17a">
#   <caption>Expected Classes</caption>
#   <thead>
#     <tr>
#       <th id="T_9b17a_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_9b17a_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_9b17a_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9b17a_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_9b17a_row0_col1" class="data row0 col1" >669</td>
#       <td id="T_9b17a_row0_col2" class="data row0 col2" >66.9%</td>
#     </tr>
#     <tr>
#       <td id="T_9b17a_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_9b17a_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_9b17a_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_9b17a_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_9b17a_row2_col1" class="data row2 col1" >109</td>
#       <td id="T_9b17a_row2_col2" class="data row2 col2" >10.9%</td>
#     </tr>
#     <tr>
#       <td id="T_9b17a_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_9b17a_row3_col1" class="data row3 col1" >51</td>
#       <td id="T_9b17a_row3_col2" class="data row3 col2" >5.1%</td>
#     </tr>
#     <tr>
#       <td id="T_9b17a_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_9b17a_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_9b17a_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_9b17a_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_9b17a_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_9b17a_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_9b17a_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_9b17a_row6_col1" class="data row6 col1" >12</td>
#       <td id="T_9b17a_row6_col2" class="data row6 col2" >1.2%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_25b13 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_25b13 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_25b13 table {
#   width: 100%;
# }
# </style>
# <table id="T_25b13">
#   <caption>Classified Predictions</caption>
#   <thead>
#     <tr>
#       <th id="T_25b13_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_25b13_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_25b13_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_25b13_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_25b13_row0_col1" class="data row0 col1" >748</td>
#       <td id="T_25b13_row0_col2" class="data row0 col2" >74.8%</td>
#     </tr>
#     <tr>
#       <td id="T_25b13_row1_col0" class="data row1 col0" >benign keratosis-like lesions</td>
#       <td id="T_25b13_row1_col1" class="data row1 col1" >77</td>
#       <td id="T_25b13_row1_col2" class="data row1 col2" >7.7%</td>
#     </tr>
#     <tr>
#       <td id="T_25b13_row2_col0" class="data row2 col0" >actinic keratoses</td>
#       <td id="T_25b13_row2_col1" class="data row2 col1" >54</td>
#       <td id="T_25b13_row2_col2" class="data row2 col2" >5.4%</td>
#     </tr>
#     <tr>
#       <td id="T_25b13_row3_col0" class="data row3 col0" >melanoma</td>
#       <td id="T_25b13_row3_col1" class="data row3 col1" >51</td>
#       <td id="T_25b13_row3_col2" class="data row3 col2" >5.1%</td>
#     </tr>
#     <tr>
#       <td id="T_25b13_row4_col0" class="data row4 col0" >basal cell carcinoma</td>
#       <td id="T_25b13_row4_col1" class="data row4 col1" >48</td>
#       <td id="T_25b13_row4_col2" class="data row4 col2" >4.8%</td>
#     </tr>
#     <tr>
#       <td id="T_25b13_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_25b13_row5_col1" class="data row5 col1" >13</td>
#       <td id="T_25b13_row5_col2" class="data row5 col2" >1.3%</td>
#     </tr>
#     <tr>
#       <td id="T_25b13_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_25b13_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_25b13_row6_col2" class="data row6 col2" >0.9%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + LoRA (500 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_91ab9 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_91ab9 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_91ab9 table {
#   width: 100%;
# }
# </style>
# <table id="T_91ab9">
#   <caption>Expected Classes</caption>
#   <thead>
#     <tr>
#       <th id="T_91ab9_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_91ab9_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_91ab9_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_91ab9_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_91ab9_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_91ab9_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_91ab9_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_91ab9_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_91ab9_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_91ab9_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_91ab9_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_91ab9_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_91ab9_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_91ab9_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_91ab9_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_91ab9_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_91ab9_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_91ab9_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_91ab9_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_91ab9_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_91ab9_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_91ab9_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_91ab9_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_91ab9_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_b5225 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_b5225 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_b5225 table {
#   width: 100%;
# }
# </style>
# <table id="T_b5225">
#   <caption>Classified Predictions</caption>
#   <thead>
#     <tr>
#       <th id="T_b5225_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_b5225_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_b5225_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b5225_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_b5225_row0_col1" class="data row0 col1" >598</td>
#       <td id="T_b5225_row0_col2" class="data row0 col2" >59.8%</td>
#     </tr>
#     <tr>
#       <td id="T_b5225_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_b5225_row1_col1" class="data row1 col1" >384</td>
#       <td id="T_b5225_row1_col2" class="data row1 col2" >38.4%</td>
#     </tr>
#     <tr>
#       <td id="T_b5225_row2_col0" class="data row2 col0" >basal cell carcinoma</td>
#       <td id="T_b5225_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_b5225_row2_col2" class="data row2 col2" >1.0%</td>
#     </tr>
#     <tr>
#       <td id="T_b5225_row3_col0" class="data row3 col0" >actinic keratoses</td>
#       <td id="T_b5225_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_b5225_row3_col2" class="data row3 col2" >0.7%</td>
#     </tr>
#     <tr>
#       <td id="T_b5225_row4_col0" class="data row4 col0" >dermatofibroma</td>
#       <td id="T_b5225_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_b5225_row4_col2" class="data row4 col2" >0.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + LoRA (1000 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_f1ad2 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_f1ad2 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_f1ad2 table {
#   width: 100%;
# }
# </style>
# <table id="T_f1ad2">
#   <caption>Expected Classes</caption>
#   <thead>
#     <tr>
#       <th id="T_f1ad2_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_f1ad2_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_f1ad2_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f1ad2_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_f1ad2_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_f1ad2_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_f1ad2_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_f1ad2_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_f1ad2_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_f1ad2_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_f1ad2_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_f1ad2_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_f1ad2_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_f1ad2_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_f1ad2_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_f1ad2_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_f1ad2_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_f1ad2_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_f1ad2_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_f1ad2_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_f1ad2_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_f1ad2_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_f1ad2_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_f1ad2_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_f699a caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_f699a th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_f699a table {
#   width: 100%;
# }
# </style>
# <table id="T_f699a">
#   <caption>Classified Predictions</caption>
#   <thead>
#     <tr>
#       <th id="T_f699a_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_f699a_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_f699a_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f699a_row0_col0" class="data row0 col0" >melanoma</td>
#       <td id="T_f699a_row0_col1" class="data row0 col1" >567</td>
#       <td id="T_f699a_row0_col2" class="data row0 col2" >56.7%</td>
#     </tr>
#     <tr>
#       <td id="T_f699a_row1_col0" class="data row1 col0" >melanocytic Nevi</td>
#       <td id="T_f699a_row1_col1" class="data row1 col1" >408</td>
#       <td id="T_f699a_row1_col2" class="data row1 col2" >40.8%</td>
#     </tr>
#     <tr>
#       <td id="T_f699a_row2_col0" class="data row2 col0" >actinic keratoses</td>
#       <td id="T_f699a_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_f699a_row2_col2" class="data row2 col2" >1.3%</td>
#     </tr>
#     <tr>
#       <td id="T_f699a_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_f699a_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_f699a_row3_col2" class="data row3 col2" >0.8%</td>
#     </tr>
#     <tr>
#       <td id="T_f699a_row4_col0" class="data row4 col0" >dermatofibroma</td>
#       <td id="T_f699a_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_f699a_row4_col2" class="data row4 col2" >0.4%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>
# <h2>LLaMA + LoRA (5000 samples)</h2>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <div>
#             <style type="text/css">
# #T_8cef8 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_8cef8 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_8cef8 table {
#   width: 100%;
# }
# </style>
# <table id="T_8cef8">
#   <caption>Expected Classes</caption>
#   <thead>
#     <tr>
#       <th id="T_8cef8_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_8cef8_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_8cef8_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8cef8_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_8cef8_row0_col1" class="data row0 col1" >668</td>
#       <td id="T_8cef8_row0_col2" class="data row0 col2" >66.8%</td>
#     </tr>
#     <tr>
#       <td id="T_8cef8_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_8cef8_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_8cef8_row1_col2" class="data row1 col2" >11.2%</td>
#     </tr>
#     <tr>
#       <td id="T_8cef8_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_8cef8_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_8cef8_row2_col2" class="data row2 col2" >11.0%</td>
#     </tr>
#     <tr>
#       <td id="T_8cef8_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_8cef8_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_8cef8_row3_col2" class="data row3 col2" >5.2%</td>
#     </tr>
#     <tr>
#       <td id="T_8cef8_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_8cef8_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_8cef8_row4_col2" class="data row4 col2" >3.3%</td>
#     </tr>
#     <tr>
#       <td id="T_8cef8_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_8cef8_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_8cef8_row5_col2" class="data row5 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <td id="T_8cef8_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_8cef8_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_8cef8_row6_col2" class="data row6 col2" >1.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div>
#             <style type="text/css">
# #T_abee5 caption {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_abee5 th {
#   text-align: left;
#   background-color: #f0f0f0;
# }
# #T_abee5 table {
#   width: 100%;
# }
# </style>
# <table id="T_abee5">
#   <caption>Classified Predictions</caption>
#   <thead>
#     <tr>
#       <th id="T_abee5_level0_col0" class="col_heading level0 col0" >Answer</th>
#       <th id="T_abee5_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_abee5_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_abee5_row0_col0" class="data row0 col0" >melanocytic Nevi</td>
#       <td id="T_abee5_row0_col1" class="data row0 col1" >716</td>
#       <td id="T_abee5_row0_col2" class="data row0 col2" >71.6%</td>
#     </tr>
#     <tr>
#       <td id="T_abee5_row1_col0" class="data row1 col0" >melanoma</td>
#       <td id="T_abee5_row1_col1" class="data row1 col1" >117</td>
#       <td id="T_abee5_row1_col2" class="data row1 col2" >11.7%</td>
#     </tr>
#     <tr>
#       <td id="T_abee5_row2_col0" class="data row2 col0" >benign keratosis-like lesions</td>
#       <td id="T_abee5_row2_col1" class="data row2 col1" >66</td>
#       <td id="T_abee5_row2_col2" class="data row2 col2" >6.6%</td>
#     </tr>
#     <tr>
#       <td id="T_abee5_row3_col0" class="data row3 col0" >basal cell carcinoma</td>
#       <td id="T_abee5_row3_col1" class="data row3 col1" >60</td>
#       <td id="T_abee5_row3_col2" class="data row3 col2" >6.0%</td>
#     </tr>
#     <tr>
#       <td id="T_abee5_row4_col0" class="data row4 col0" >actinic keratoses</td>
#       <td id="T_abee5_row4_col1" class="data row4 col1" >26</td>
#       <td id="T_abee5_row4_col2" class="data row4 col2" >2.6%</td>
#     </tr>
#     <tr>
#       <td id="T_abee5_row5_col0" class="data row5 col0" >vascular lesions</td>
#       <td id="T_abee5_row5_col1" class="data row5 col1" >12</td>
#       <td id="T_abee5_row5_col2" class="data row5 col2" >1.2%</td>
#     </tr>
#     <tr>
#       <td id="T_abee5_row6_col0" class="data row6 col0" >dermatofibroma</td>
#       <td id="T_abee5_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_abee5_row6_col2" class="data row6 col2" >0.3%</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
#     <br><hr><br>

# %% [markdown]
# ### Análise

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix


def analyze_model_performance(pairs: list[tuple[str, str]], model_name: str):
    """Calculate accuracy and create normalized confusion matrix visualization"""
    y_true = [p[0] for p in pairs]
    y_pred = [p[1] for p in pairs]

    # Calculate accuracy
    accuracy = accuracy_score(y_true, y_pred)

    # Create confusion matrix
    labels = DISEASE_CLASSES + ['unclear answer']
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    # Safe normalization with handling for zero division
    row_sums = cm.sum(axis=1)
    cm_normalized = np.zeros_like(cm, dtype=float)
    for i in range(len(row_sums)):
        if row_sums[i] > 0:  # Only normalize non-empty classes
            cm_normalized[i] = cm[i] / row_sums[i]

    # Plot confusion matrix
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt='.1%',
                cmap='Blues',
                xticklabels=labels,
                yticklabels=labels,
                vmin=0,
                vmax=1,
                cbar_kws={'label': 'Normalized by true label'})
    plt.title(f'{model_name}\nAccuracy: {accuracy:.2%}')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

    return accuracy


print("Model Accuracies:")
accuracies = {}
for model_name, pairs in all_results.items():
    accuracies[model_name] = analyze_model_performance(pairs, model_name)
# Out:
# Model Accuracies:
